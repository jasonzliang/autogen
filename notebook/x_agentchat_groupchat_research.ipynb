# %% [markdown]
# <a href="https://colab.research.google.com/github/microsoft/autogen/blob/main/notebook/agentchat_groupchat_research.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Auto Generated Agent Chat: Performs Research with Multi-Agent Group Chat
#
# AutoGen offers conversable agents powered by LLM, tool, or human, which can be used to perform tasks collectively via automated chat. This framework allows tool use and human participation through multi-agent conversation.
# Please find documentation about this feature [here](https://microsoft.github.io/autogen/docs/Use-Cases/agent_chat).
#
# ## Requirements
#
# AutoGen requires `Python>=3.8`. To run this notebook example, please install:
# ```bash
# pip install pyautogen
# ```

# %%
pip install "pyautogen>=0.2.3"
# Out:
# Requirement already satisfied: pyautogen>=0.2.3 in /home/jason/dl_env/lib/python3.10/site-packages (0.2.11)
# Requirement already satisfied: diskcache in /home/jason/dl_env/lib/python3.10/site-packages (from pyautogen>=0.2.3) (5.6.3)
# Requirement already satisfied: docker in /home/jason/dl_env/lib/python3.10/site-packages (from pyautogen>=0.2.3) (7.0.0)
# Requirement already satisfied: flaml in /home/jason/dl_env/lib/python3.10/site-packages (from pyautogen>=0.2.3) (2.1.1)
# Requirement already satisfied: openai>=1.3 in /home/jason/dl_env/lib/python3.10/site-packages (from pyautogen>=0.2.3) (1.11.1)
# Requirement already satisfied: pydantic<3,>=1.10 in /home/jason/dl_env/lib/python3.10/site-packages (from pyautogen>=0.2.3) (2.6.1)
# Requirement already satisfied: python-dotenv in /home/jason/dl_env/lib/python3.10/site-packages (from pyautogen>=0.2.3) (1.0.0)
# Requirement already satisfied: termcolor in /home/jason/dl_env/lib/python3.10/site-packages (from pyautogen>=0.2.3) (2.3.0)
# Requirement already satisfied: tiktoken in /home/jason/dl_env/lib/python3.10/site-packages (from pyautogen>=0.2.3) (0.5.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/jason/dl_env/lib/python3.10/site-packages (from openai>=1.3->pyautogen>=0.2.3) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/jason/dl_env/lib/python3.10/site-packages (from openai>=1.3->pyautogen>=0.2.3) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/jason/dl_env/lib/python3.10/site-packages (from openai>=1.3->pyautogen>=0.2.3) (0.26.0)
# Requirement already satisfied: sniffio in /home/jason/dl_env/lib/python3.10/site-packages (from openai>=1.3->pyautogen>=0.2.3) (1.3.0)
# Requirement already satisfied: tqdm>4 in /home/jason/dl_env/lib/python3.10/site-packages (from openai>=1.3->pyautogen>=0.2.3) (4.66.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /home/jason/dl_env/lib/python3.10/site-packages (from openai>=1.3->pyautogen>=0.2.3) (4.9.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/jason/dl_env/lib/python3.10/site-packages (from pydantic<3,>=1.10->pyautogen>=0.2.3) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /home/jason/dl_env/lib/python3.10/site-packages (from pydantic<3,>=1.10->pyautogen>=0.2.3) (2.16.2)
# Requirement already satisfied: packaging>=14.0 in /home/jason/dl_env/lib/python3.10/site-packages (from docker->pyautogen>=0.2.3) (23.1)
# Requirement already satisfied: requests>=2.26.0 in /home/jason/dl_env/lib/python3.10/site-packages (from docker->pyautogen>=0.2.3) (2.31.0)
# Requirement already satisfied: urllib3>=1.26.0 in /home/jason/dl_env/lib/python3.10/site-packages (from docker->pyautogen>=0.2.3) (2.0.2)
# Requirement already satisfied: NumPy>=1.17.0rc1 in /home/jason/dl_env/lib/python3.10/site-packages (from flaml->pyautogen>=0.2.3) (1.23.5)
# Requirement already satisfied: regex>=2022.1.18 in /home/jason/dl_env/lib/python3.10/site-packages (from tiktoken->pyautogen>=0.2.3) (2023.5.5)
# Requirement already satisfied: idna>=2.8 in /home/jason/dl_env/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai>=1.3->pyautogen>=0.2.3) (3.4)
# Requirement already satisfied: exceptiongroup in /home/jason/dl_env/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai>=1.3->pyautogen>=0.2.3) (1.1.3)
# Requirement already satisfied: certifi in /home/jason/dl_env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai>=1.3->pyautogen>=0.2.3) (2023.5.7)
# Requirement already satisfied: httpcore==1.* in /home/jason/dl_env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai>=1.3->pyautogen>=0.2.3) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/jason/dl_env/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.3->pyautogen>=0.2.3) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jason/dl_env/lib/python3.10/site-packages (from requests>=2.26.0->docker->pyautogen>=0.2.3) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Set your API Endpoint
#
# The [`config_list_from_json`](https://microsoft.github.io/autogen/docs/reference/oai/openai_utils#config_list_from_json) function loads a list of configurations from an environment variable or a json file.

# %%
import autogen

config_list_gpt4 = autogen.config_list_from_json(
    "OAI_CONFIG_LIST",
    filter_dict={
        "model": ["gpt-4-32k", "gpt-4-32k-0314", "gpt-4-32k-v0314"],
    },
)

# %% [markdown]
# It first looks for environment variable "OAI_CONFIG_LIST" which needs to be a valid json string. If that variable is not found, it then looks for a json file named "OAI_CONFIG_LIST". It filters the configs by models (you can filter by other keys as well).
#
# The config list looks like the following:
# ```python
# config_list = [
#     {
#         'model': 'gpt-4-32k',
#         'api_key': '<your OpenAI API key here>',
#     },
#     {
#         'model': 'gpt-4-32k',
#         'api_key': '<your Azure OpenAI API key here>',
#         'base_url': '<your Azure OpenAI API base here>',
#         'api_type': 'azure',
#         'api_version': '2023-06-01-preview',
#     },
#     {
#         'model': 'gpt-4-32k-0314',
#         'api_key': '<your Azure OpenAI API key here>',
#         'base_url': '<your Azure OpenAI API base here>',
#         'api_type': 'azure',
#         'api_version': '2023-06-01-preview',
#     },
# ]
# ```
#
# You can set the value of config_list in any way you prefer. Please refer to this [notebook](https://github.com/microsoft/autogen/blob/main/website/docs/llm_endpoint_configuration.ipynb) for full code examples of the different methods.

# %% [markdown]
# ## Construct Agents

# %%
gpt4_config = {
    "cache_seed": 42,  # change the cache_seed for different trials
    "temperature": 0,
    "config_list": config_list_gpt4,
    "timeout": 120,
}
user_proxy = autogen.UserProxyAgent(
    name="Admin",
    system_message="A human admin. Interact with the planner to discuss the plan. Plan execution needs to be approved by this admin.",
    code_execution_config=False,
)
engineer = autogen.AssistantAgent(
    name="Engineer",
    llm_config=gpt4_config,
    system_message="""Engineer. You follow an approved plan. You write python/shell code to solve tasks. Wrap the code in a code block that specifies the script type. The user can't modify your code. So do not suggest incomplete code which requires others to modify. Don't use a code block if it's not intended to be executed by the executor.
Don't include multiple code blocks in one response. Do not ask others to copy and paste the result. Check the execution result returned by the executor.
If the result indicates there is an error, fix the error and output the code again. Suggest the full code instead of partial code or code changes. If the error can't be fixed or if the task is not solved even after the code is executed successfully, analyze the problem, revisit your assumption, collect additional info you need, and think of a different approach to try.
""",
)
scientist = autogen.AssistantAgent(
    name="Scientist",
    llm_config=gpt4_config,
    system_message="""Scientist. You follow an approved plan. You are able to categorize papers after seeing their abstracts printed. You don't write code.""",
)
planner = autogen.AssistantAgent(
    name="Planner",
    system_message="""Planner. Suggest a plan. Revise the plan based on feedback from admin and critic, until admin approval.
The plan may involve an engineer who can write code and a scientist who doesn't write code.
Explain the plan first. Be clear which step is performed by an engineer, and which step is performed by a scientist.
""",
    llm_config=gpt4_config,
)
executor = autogen.UserProxyAgent(
    name="Executor",
    system_message="Executor. Execute the code written by the engineer and report the result.",
    human_input_mode="NEVER",
    code_execution_config={
        "last_n_messages": 3,
        "work_dir": "paper",
        "use_docker": False,
    },  # Please set use_docker=True if docker is available to run the generated code. Using docker is safer than running the generated code directly.
)
critic = autogen.AssistantAgent(
    name="Critic",
    system_message="Critic. Double check plan, claims, code from other agents and provide feedback. Check whether the plan includes adding verifiable info such as source URL.",
    llm_config=gpt4_config,
)
groupchat = autogen.GroupChat(
    agents=[user_proxy, engineer, scientist, planner, executor, critic], messages=[], max_round=50
)
manager = autogen.GroupChatManager(groupchat=groupchat, llm_config=gpt4_config)
# Out:
# [autogen.oai.client: 02-06 20:46:51] {351} WARNING - openai client was provided with an empty config_list, which may not be intended.
# [autogen.oai.client: 02-06 20:46:51] {351} WARNING - openai client was provided with an empty config_list, which may not be intended.
# [autogen.oai.client: 02-06 20:46:51] {351} WARNING - openai client was provided with an empty config_list, which may not be intended.
# [autogen.oai.client: 02-06 20:46:51] {351} WARNING - openai client was provided with an empty config_list, which may not be intended.
# [autogen.oai.client: 02-06 20:46:51] {351} WARNING - openai client was provided with an empty config_list, which may not be intended.

# %% [markdown]
# ## Start Chat

# %%
user_proxy.initiate_chat(
    manager,
    message="""
find papers on LLM applications from arxiv in the last week, create a markdown table of different domains.
""",
)
# Out:
# Admin (to chat_manager):
#
#
# find papers on LLM applications from arxiv in the last week, create a markdown table of different domains.
#
#
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 user_proxy.initiate_chat(
#       2     manager,
#       3     message="""
#       4 find papers on LLM applications from arxiv in the last week, create a markdown table of different domains.
#       5 """,
#       6 )
#
# File ~/dl_env/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:746, in ConversableAgent.initiate_chat(self, recipient, clear_history, silent, cache, **context)
#     744     agent.client_cache = cache
#     745 self._prepare_chat(recipient, clear_history)
# --> 746 self.send(self.generate_init_message(**context), recipient, silent=silent)
#     747 summary = self._summarize_chat(
#     748     context.get("summary_method"),
#     749     recipient,
#     750     prompt=context.get("summary_prompt"),
#     751     cache=cache,
#     752 )
#     753 for agent in [self, recipient]:
#
# File ~/dl_env/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:457, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#     455 valid = self._append_oai_message(message, "assistant", recipient)
#     456 if valid:
# --> 457     recipient.receive(message, self, request_reply, silent)
#     458 else:
#     459     raise ValueError(
#     460         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#     461     )
#
# File ~/dl_env/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:632, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#     630 if request_reply is False or request_reply is None and self.reply_at_receive[sender] is False:
#     631     return
# --> 632 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#     633 if reply is not None:
#     634     self.send(reply, sender, silent=silent)
#
# File ~/dl_env/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:1546, in ConversableAgent.generate_reply(self, messages, sender, exclude)
#    1544     continue
#    1545 if self._match_trigger(reply_func_tuple["trigger"], sender):
# -> 1546     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    1547     if final:
#    1548         return reply
#
# File ~/dl_env/lib/python3.10/site-packages/autogen/agentchat/groupchat.py:518, in GroupChatManager.run_chat(self, messages, sender, config)
#     515     break
#     516 try:
#     517     # select the next speaker
# --> 518     speaker = groupchat.select_speaker(speaker, self)
#     519     # let the speaker speak
#     520     reply = speaker.generate_reply(sender=self)
#
# File ~/dl_env/lib/python3.10/site-packages/autogen/agentchat/groupchat.py:365, in GroupChat.select_speaker(self, last_speaker, selector)
#     363 # auto speaker selection
#     364 selector.update_system_message(self.select_speaker_msg(agents))
# --> 365 final, name = selector.generate_oai_reply(messages)
#     366 return self._finalize_speaker(last_speaker, final, name, agents)
#
# File ~/dl_env/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:1035, in ConversableAgent.generate_oai_reply(self, messages, sender, config)
#    1032         all_messages.append(message)
#    1034 # TODO: #1143 handle token limit exceeded error
# -> 1035 response = client.create(
#    1036     context=messages[-1].pop("context", None),
#    1037     messages=self._oai_system_message + all_messages,
#    1038     cache=self.client_cache,
#    1039 )
#    1041 extracted_response = client.extract_text_or_completion_object(response)[0]
#    1043 if extracted_response is None:
#
# File ~/dl_env/lib/python3.10/site-packages/autogen/oai/client.py:583, in OpenAIWrapper.create(self, **config)
#     581             continue  # filter is not passed; try the next config
#     582 try:
# --> 583     response = client.create(params)
#     584 except APIError as err:
#     585     error_code = getattr(err, "code", None)
#
# File ~/dl_env/lib/python3.10/site-packages/autogen/oai/client.py:267, in OpenAIClient.create(self, params)
#     265     params = params.copy()
#     266     params["stream"] = False
# --> 267     response = completions.create(**params)
#     269 return response
#
# File ~/dl_env/lib/python3.10/site-packages/openai/_utils/_utils.py:270, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     268         else:
#     269             msg = f"Missing required argument: {quote(missing[0])}"
# --> 270     raise TypeError(msg)
#     271 return func(*args, **kwargs)
#
# TypeError: Missing required arguments; Expected either ('messages' and 'model') or ('messages', 'model' and 'stream') arguments to be given

# %% [markdown]
# ## Create Group Chat without Critic for Comparison

# %%
groupchat_nocritic = autogen.GroupChat(
    agents=[user_proxy, engineer, scientist, planner, executor], messages=[], max_round=50
)
for agent in groupchat.agents:
    agent.reset()
manager_nocritic = autogen.GroupChatManager(groupchat=groupchat_nocritic, llm_config=gpt4_config)
user_proxy.initiate_chat(
    manager_nocritic,
    message="""
find papers on LLM applications from arxiv in the last week, create a markdown table of different domains.
""",
)
